# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
df = data[['AirportFrom','Delay']].groupby('AirportFrom').agg('count').reset_index()
pd.set_option('display.max_rows', None, 'display.max_columns', None)
df
#fig = px.bar(df, x='AirportFrom', y='Delay',template="ggplot2")
#fig.show()
# Out:
#     AirportFrom  Delay
# 0           ABE    342
# 1           ABI    211
# 2           ABQ   2799
# 3           ABR      2
# 4           ABY     87
# 5           ACT     60
# 6           ACV    296
# 7           ACY     62
# 8           ADK      9
# 9           ADQ     56
# 10          AEX    286
# 11          AGS    322
# 12          ALB    951
# 13          AMA    482
# 14          ANC   1307
# 15          ASE    458
# 16          ATL  34449
# 17          ATW    378
# 18          AUS   3654
# 19          AVL    426
# 20          AVP    199
# 21          AZO    243
# 22          BDL   2280
# 23          BET     84
# 24          BFL    276
# 25          BGM     74
# 26          BGR     32
# 27          BHM   1756
# 28          BIL    306
# 29          BIS    324
# 30          BKG     60
# 31          BLI     26
# 32          BMI    405
# 33          BNA   4353
# 34          BOI   1208
# 35          BOS   9439
# 36          BQK     87
# 37          BQN    137
# 38          BRO    207
# ...

# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
df = data[['Length','Delay']].groupby('Length').agg('count').reset_index()
fig = px.scatter(df, x='Length', y='Delay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
data.groupby(by = ['DayOfWeek', 'Airline']).Delay.mean().sort_index().unstack().plot.barh(subplots=True, figsize=(20,40))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f527254e790>,
# ...
#       dtype=object)

# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
data['Route']=data['AirportFrom']+'-'+data['AirportTo']
sns.distplot(data['Length'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
df.corr()
#fig = px.bar(df, x='AirportFrom', y='Delay',template="ggplot2")
#fig.show()
# Out:
#        Delay
# Delay    1.0

# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop('id', axis=1, inplace = True)
delay = data.replace({'Delay': {0: 'No Delay', 1: 'Delay'}})
delay.groupby(by = ['Airline', 'Delay']).Delay.count().unstack().plot.bar()
