# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = pd.read_csv('Airlines.csv')
airports = pd.read_csv('airports.csv')

# %%
flights.head()
# Out:
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0

# %%
airports.head()
# Out:
#   IATA                              AIRPORT           CITY STATE COUNTRY  \
# 0  ABQ            Albuquerque International    Albuquerque    NM     USA
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK     USA
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA     USA
# 3  AUS       Austin-Bergstrom International         Austin    TX     USA
# 4  BDL                Bradley International  Windsor Locks    CT     USA
#
#     LATITUDE   LONGITUDE
# 0  35.040222 -106.609194
# 1  61.174320 -149.996186
# 2  33.640444  -84.426944
# 3  30.194533  -97.669872
# 4  41.938874  -72.683228

# %% [markdown]
# ## Finalized Visualizations:
#
# Example:
#
# \(not great visualization cause too many airports, but looks kinda cool\)

# %% [markdown]
# Description of visualization in markdown cell
#
# - What is being shown
# - What are the main takeaways
#
# We see that larger airports \(Atlanta, O'Hare, Denver, DFW, LAX\) have the highest proportion of delays to overall number of flights taking off.

# %%
delayed = flights[flights['Delay'] == 1]
airport_from_delay_props = (flights.groupby('AirportFrom').sum()['Delay'] / delayed.shape[0]).sort_values()
labels = airport_from_delay_props.index
values = airport_from_delay_props.values

import plotly.graph_objects as go
fig = go.Figure(data=[go.Pie(labels=labels, values=values, sort = False, title = "Proportion of Delays by Take Off Airport")])
fig.update_traces(textposition='inside')
fig.update_layout(uniformtext_minsize=12, uniformtext_mode='hide')
fig.write_html('airport_pie.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="164f4352-1232-481a-a03d-6ac15613010c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("164f4352-1232-481a-a03d-6ac15613010c")) {                    Plotly.newPlot(                        "164f4352-1232-481a-a03d-6ac15613010c",                        [{"labels":["ABR","SJT","MMH","TEX","ADK","GUM","UTM","CYS","HTS","PIE","GGG","DBQ","BLI","TXK","YAK","GTR","PLN","CLL","FLO","SPS","TOL","CDV","IPL","BKG","LCH","SCC","ACY","TYR","MEI","BGR","LWB","ACT","EWN","PSE","WRG","ADQ","MKG","LYH","CMX","IYK","VLD","CHO","STX","BTM","BQK","ABY","PAH","PSG","SIT","FLG","MQT","CDC","FSM","COU","DHN","ERI","SAF","ABI","GUC","ROW","BGM","LWS","EAU","SMX","COD","SCE","ITH","BRW","RDD","LSE","LMT","ELM","CEC","MHK","MLB","GTF","OME","FCA","BET","GCC","SPI","EYW","CIC","RST","BRO","HDN","OTZ","PIH","HLN","MLU","CPR","CSG","KTN","LRD","CMI","MOD","EKO","SUN","CWA","BQN","DAB","OTH","OAJ","TWF","SWF","AZO","MYR","STT","CLD","IDA","RKS","LNK","LAN","MTJ","GNV","AEX","SGU","BIL","GRK","ILM","EGE","GFK","SHV","DLH","AVP","MOT","MFE","DRO","LFT","MBS","EVV","BFL","YUM","PIA","JAC","BZN","MSO","TRI","TVC","FAY","JNU","ROA","CHA","ABE","ATW","MGM","AGS","GJT","RDM","FAI","SRQ","PSC","MFR","HRL","GPT","BIS","MOB","TLH","MRY","FWA","RAP","ACV","SBP","PWM","ITO","CRW","CID","MDT","SGF","AVL","BMI","CRP","ECP","ASE","PHF","FAR","GRB","FNT","EUG","FSD","BTR","SBN","MAF","VPS","MLI","BTV","KOA","AMA","HSV","CAE","LIH","PNS","LBB","ICT","SAV","MSN","CAK","GSP","GSO","SBA","CHS","XNA","HPN","LEX","ISP","JAN","COS","GRR","FAT","PSP","TYS","DSM","DAY","ALB","ANC","MHT","SYR","OGG","ROC","GEG","LGB","RIC","ORF","LIT","PVD","TUL","TUS","BOI","SDF","OKC","SJU","OMA","ELP","BHM","RSW","PBI","JAX","BUF","RNO","ONT","BDL","BUR","CMH","IND","MSY","SAT","ABQ","HNL","PIT","AUS","RDU","SNA","CVG","MKE","SJC","PDX","CLE","MEM","MCI","SMF","DCA","BNA","TPA","IAD","FLL","OAK","DAL","MIA","STL","HOU","LGA","PHL","SEA","SAN","BOS","JFK","CLT","MCO","EWR","BWI","MSP","MDW","SLC","SFO","DTW","LAS","PHX","IAH","LAX","DFW","DEN","ORD","ATL"],"sort":false,"title":{"text":"Proportion of Delays by Take Off Airport"},"values":[4.162088369460261e-06,1.6648353477841043e-05,1.6648353477841043e-05,1.6648353477841043e-05,2.0810441847301303e-05,2.4972530216761563e-05,2.4972530216761563e-05,2.9134618586221823e-05,2.9134618586221823e-05,2.9134618586221823e-05,3.3296706955682086e-05,3.7458795325142346e-05,3.7458795325142346e-05,3.7458795325142346e-05,3.7458795325142346e-05,3.7458795325142346e-05,4.1620883694602606e-05,4.1620883694602606e-05,4.5782972064062866e-05,4.9945060433523126e-05,5.4107148802983385e-05,5.4107148802983385e-05,5.4107148802983385e-05,5.4107148802983385e-05,6.243132554190391e-05,6.243132554190391e-05,6.659341391136417e-05,6.659341391136417e-05,6.659341391136417e-05,6.659341391136417e-05,6.659341391136417e-05,7.075550228082443e-05,7.075550228082443e-05,7.075550228082443e-05,7.491759065028469e-05,7.491759065028469e-05,7.491759065028469e-05,7.907967901974495e-05,7.907967901974495e-05,7.907967901974495e-05,8.324176738920521e-05,8.740385575866547e-05,8.740385575866547e-05,8.740385575866547e-05,9.156594412812573e-05,9.156594412812573e-05,9.572803249758599e-05,9.989012086704625e-05,0.00010405220923650651,0.00010821429760596677,0.00010821429760596677,0.00011237638597542703,0.00011653847434488729,0.00011653847434488729,0.00011653847434488729,0.00011653847434488729,0.00012070056271434755,0.00013318682782272834,0.00013318682782272834,0.00013318682782272834,0.0001373489161921886,0.0001373489161921886,0.00014151100456164886,0.00014151100456164886,0.00014567309293110912,0.00014567309293110912,0.00014983518130056938,0.00015399726967002964,0.00016232144640895016,0.00016648353477841042,0.000170645623147 ...

# %%
flights.corr()
# Out:
#                  id    Flight  DayOfWeek      Time    Length     Delay
# id         1.000000 -0.006156  -0.055474  0.029156  0.020781  0.139762
# Flight    -0.006156  1.000000   0.000416 -0.005750 -0.341481 -0.046175
# DayOfWeek -0.055474  0.000416   1.000000  0.001273  0.013397 -0.026199
# Time       0.029156 -0.005750   0.001273  1.000000 -0.020612  0.150454
# Length     0.020781 -0.341481   0.013397 -0.020612  1.000000  0.040489
# Delay      0.139762 -0.046175  -0.026199  0.150454  0.040489  1.000000

# %% [markdown]
# ### Delayed Airports in the United States and Territories
#
# Here we find 292 airports spread across the United States, Guam, and Puerto Rico. This visualization shows all the airports placed using information from the "Airport Coordinates" comma seperated values file. This file includes data like the airport's: acronym, latitude, longitude, name, and percentage of flights that were delayed.

# %%
df = pd.read_csv("Airport Coordinates.csv")
# df['text'] = df['IATA'] + ',' + df['AIRPORT'] + ',' + df['DELAY'].astype(str)
df['text'] = df['IATA'] + ', ' + df['AIRPORT'] + '</br>' + df['DELAY'].astype(str) + '% delay'

fig = go.Figure(data=go.Scattergeo(
        lon = df['LONGITUDE'],
        lat = df['LATITUDE'],
        text = df['text'],
        mode = 'markers',
        marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 
614361,40.85097222,27.54373861,43.87937972,37.85830556,46.37449806,37.32668528,31.94252778,43.53291472,39.29760528,28.42888889,40.19349528,41.7859825,32.33313333,35.04241667,26.17583333,42.37422778,32.30064417,39.14096722,42.93451639,25.79325,42.94722222,43.16948806,28.10275,41.44852639,32.51086556,37.62404861,30.69141667,37.62581722,48.25937778,46.353639,36.5869825,43.13985778,46.91630556,44.88054694,29.99338889,38.50886722,33.67975,34.82916444,37.72129083,20.89864972,35.39308833,41.30251861,64.51220222,34.056,41.979595,36.89461111,43.41713889,66.88467694,37.06083333,26.68316194,45.58872222,37.13189556,39.87195278,33.43416667,40.66424333,27.91076333,42.91130556,40.49146583,45.5709275,30.47330556,46.26468028,18.00830278,56.80165194,33.82921556,41.72399917,43.64616667,44.04532139,40.50898361,44.25406722,35.87763889,37.50516667,41.5942175,39.49857611,37.32546833,43.11886611,33.30155556,43.90882639,26.53616667,35.61677778,32.73355611,29.53369444,32.12758333,34.42621194,41.70895361,35.23705806,70.19475583,40.851206,38.17438889,47.44898194,37.61900194,37.24432611,37.09058333,32.4466275,57.04713806,37.36186194,31.35775,18.43941667,40.78838778,38.69542167,34.89924833,33.67565861,39.84395194,33.98879611,27.39533333,38.74768694,18.33730556,17.70188889,43.50484139,41.50409361,43.11118694,37.95375861,30.39652778,41.58680556,27.97547222,36.47521417,36.19837222,32.11608333,44.74144472,42.48180389,33.45370806,32.35413889,35.81248722,34.68329869,30.7825,30.48325,56.48432583,36.28186944,59.50336056,32.65658333],"lon":[-75.44040167, ...

# %%
df = pd.read_csv("Airport Coordinates.csv")
df['text'] = df['IATA'] + ', ' + df['AIRPORT'] + '</br>' +  (df["SIZE"]*1000).astype(str) + ' sq. ft. (sum of runway length) </br>' + df['DELAY'].astype(str) + '% delay'

fig = go.Figure(data=go.Scattergeo(
        lon = df['LONGITUDE'],
        lat = df['LATITUDE'],
        text = df['text'],
        mode = 'markers',
        marker = dict(
            size = df['SIZE']/2,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'circle',
            line = dict(
                width=0.3,
                color='rgba(102, 102, 102)'
            ),
#             colorscale = [[0, 'red'], [0.25, 'orange'], [0.5, 'green'], [0.75, 'blue'], [1, 'purple']],
            colorscale = [[0, 'red'], [0.3, 'orange'], [0.5, 'yellow'], [1, 'green']],
            cmin = 0,
            color = df['DELAY'],
            cmax = df['DELAY'].max(),
            colorbar_title="Likelihood of Delays<br>(In percentages)"
        )))

fig.update_layout(
        title = 'Most delayed United States airports!<br>(Hover for airport names)',
        geo = dict(
            scope='north america',
            projection_type='albers',
            showland = True,
            landcolor = "lightblue",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.25,
            subunitwidth = 0.5
        ),
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="b0457ffa-96b9-4b88-8714-8ee9df8ec316" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0457ffa-96b9-4b88-8714-8ee9df8ec316")) {                    Plotly.newPlot(                        "b0457ffa-96b9-4b88-8714-8ee9df8ec316",                        [{"lat":[40.65236278,32.41132,35.04022222,31.535515,31.61128833,40.97811528,39.45758333,51.87796389,57.74996778,31.32737167,33.369955,42.74811944,35.2193725,61.17432028,39.22316,33.64044444,44.25740806,30.19453278,35.43619444,41.33814944,42.234875,41.93887417,60.77977639
df.to_csv('lat_long.csv', index = False)

# %%
import pandas as pd
import plotly.express as px
data = pd.read_csv("Airlines.csv")
data.drop("id",axis=1,inplace=True)
df = data[["Airline","Delay"]].groupby("Airline").agg("count").reset_index()
fig = px.histogram(df.head(100),x="Airline",y="Delay",color="Airline",title="Comparing Airlines to the Amount of Delays")
fig.update_yaxes(title_text='Number of Delays')
fig.update_xaxes(title_text='Airline Flown')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="0f6f78fb-5696-47c3-b12d-1842861116b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f6f78fb-5696-47c3-b12d-1842861116b9")) {                    Plotly.newPlot(                        "0f6f78fb-5696-47c3-b12d-1842861116b9",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"9E","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"9E","offsetgroup":"9E","orientation":"v","showlegend":true,"x":["9E"],"xaxis":"x","y":[20686],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"AA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AA","offsetgroup":"AA","orientation":"v","showlegend":true,"x":["AA"],"xaxis":"x","y":[45656],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"AS","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AS","offsetgroup":"AS","orientation":"v","showlegend":true,"x":["AS"],"xaxis":"x","y":[11471],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"B6","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"B6","offsetgroup":"B6","orientation":"v","showlegend":true,"x":["B6"],"xaxis":"x","y":[18112],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"CO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"CO","offsetgroup":"CO","orientation":"v","showlegend":true,"x":["CO"],"xaxis":"x","y":[21118],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"DL","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"DL","offsetgroup":"DL","orientation":"v","showlegend":true,"x":["DL"],"xaxis":"x","y":[60940],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"EV","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"EV","offsetgroup":"EV","orientation":"v","showlegend":true,"x":["EV"],"xaxis":"x","y":[27983],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"F9","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"F9","offsetgroup":"F9","orientation":"v","showlegend":true,"x":["F9"],"xaxis":"x","y":[6456],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"FL","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"FL","offsetgroup":"FL","orientation":"v","showlegend":true,"x":["FL"],"xaxis":"x","y":[20827],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"HA","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"HA","offsetgroup":"HA","orientation":"v","showlegend":true,"x":["HA"],"xaxis":"x","y":[5578],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Airline=%{x}<br>sum of Delay=%{y}<extra></extra>","legendgroup":"MQ","marker":{"color":"#63 ...

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv("Janna/AirportFrom, Delay, Instance, Probability,Percentage.csv")
delay = df.sort_values(by=("AirportFrom"), axis=0, ascending=True)
prob_hist = px.histogram(df, x="AirportFrom", y="Percentage", title="Percentage of Delays by AirportFrom",color="AirportFrom")
prob_hist.update_yaxes(title_text='Percentage of Delays')
prob_hist.update_xaxes(title_text='AirportFrom')
prob_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="4ee4c632-d73e-4a0f-bc14-b006dd9276a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ee4c632-d73e-4a0f-bc14-b006dd9276a6")) {                    Plotly.newPlot(                        "4ee4c632-d73e-4a0f-bc14-b006dd9276a6",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ABE","offsetgroup":"ABE","orientation":"v","showlegend":true,"x":["ABE"],"xaxis":"x","y":[32.16],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABI","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ABI","offsetgroup":"ABI","orientation":"v","showlegend":true,"x":["ABI"],"xaxis":"x","y":[15.17],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABQ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ABQ","offsetgroup":"ABQ","orientation":"v","showlegend":true,"x":["ABQ"],"xaxis":"x","y":[49.12],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ABY","offsetgroup":"ABY","orientation":"v","showlegend":true,"x":["ABY"],"xaxis":"x","y":[25.29],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ACT","offsetgroup":"ACT","orientation":"v","showlegend":true,"x":["ACT"],"xaxis":"x","y":[28.33],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACV","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ACV","offsetgroup":"ACV","orientation":"v","showlegend":true,"x":["ACV"],"xaxis":"x","y":[53.04],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACY","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ACY","offsetgroup":"ACY","orientation":"v","showlegend":true,"x":["ACY"],"xaxis":"x","y":[25.81],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ADK","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ADK","offsetgroup":"ADK","orientation":"v","showlegend":true,"x":["ADK"],"xaxis":"x","y":[55.56],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ADQ","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"ADQ","offsetgroup":"ADQ","orientation":"v","showlegend":true,"x":["ADQ"],"xaxis":"x","y":[32.14],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportFrom=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"AEX","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"AEX","offsetgroup":"AEX","orientation":"v","showlegend":true,"x":["AEX"],"xaxis":"x","y":[26.57],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingrou ...

# %% [markdown]
# The three airports that have the highest percentages of delays \(from highest to lowest\) are MDW \(Chicago Midway\), DAL \(Dallas Love\), and OAK \(Metropolitan Oakland International\). This could be due to the fact that all three of these airports are in or near major cities. MDW and DAL are located in the cities in which they are named, respectively, while OAK is located near San Francisco. Chicago, Dallas, and San Francisco have populations of over a million.
#
# The three airports with the lowest percentages \(from highest to lowest\) are HTS \(Tri\-State Walker\-Long\), FLG \(Flagstaff Pulliam\), and TXK \(Texarkana Regional\-Webb\). HTS is located in Huntington, West Virginia, FLG is located in Flagstaff, Arizona, and TXK is located in Texarkana, Arkansas. All three cities have populations below 75,000
#
# This evidence suggests that the higher rates of flight delays in larger cities could be caused by their larger populations. The same reasoning can be applied to cities with smaller populations; the smaller population sizes may be the cause of lower flight delay rates.

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv("Janna/AirportTo, Delay, Instance, Percentage.csv")
delay = df.sort_values(by=("AirportTo"), axis=0, ascending=True)
at_hist = px.histogram(df, x="AirportTo", y="Percentage", title="Percentage of Delays by AirportTo",color="AirportTo")
at_hist.update_yaxes(title_text='Percentage of Delays')
at_hist.update_xaxes(title_text='AirportTo')
at_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="eca09036-3315-4bb6-9d11-df80045c0516" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eca09036-3315-4bb6-9d11-df80045c0516")) {                    Plotly.newPlot(                        "eca09036-3315-4bb6-9d11-df80045c0516",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ABE","offsetgroup":"ABE","orientation":"v","showlegend":true,"x":["ABE"],"xaxis":"x","y":[44.26],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABI","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ABI","offsetgroup":"ABI","orientation":"v","showlegend":true,"x":["ABI"],"xaxis":"x","y":[33.18],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABQ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ABQ","offsetgroup":"ABQ","orientation":"v","showlegend":true,"x":["ABQ"],"xaxis":"x","y":[58.68],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ABY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ABY","offsetgroup":"ABY","orientation":"v","showlegend":true,"x":["ABY"],"xaxis":"x","y":[31.03],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ACT","offsetgroup":"ACT","orientation":"v","showlegend":true,"x":["ACT"],"xaxis":"x","y":[28.81],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACV","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ACV","offsetgroup":"ACV","orientation":"v","showlegend":true,"x":["ACV"],"xaxis":"x","y":[55.59],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ACY","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ACY","offsetgroup":"ACY","orientation":"v","showlegend":true,"x":["ACY"],"xaxis":"x","y":[35.48],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"ADQ","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ADQ","offsetgroup":"ADQ","orientation":"v","showlegend":true,"x":["ADQ"],"xaxis":"x","y":[28.57],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"AEX","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"AEX","offsetgroup":"AEX","orientation":"v","showlegend":true,"x":["AEX"],"xaxis":"x","y":[32.04],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"AirportTo=%{x}<br>sum of Percentage=%{y}<extra></extra>","legendgroup":"AGS","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"AGS","offsetgroup":"AGS","orientation":"v","showlegend":true,"x":["AGS"],"xaxis":"x","y":[41.93],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"s ...
